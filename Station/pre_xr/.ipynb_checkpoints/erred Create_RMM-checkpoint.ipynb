# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import glob
import pickle


import cartopy.crs as ccrs
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
import matplotlib.ticker as mticker

# %%
RMM_meta = pd.read_csv('RMM_meta.csv', header = 0)

# %%
RMM_meta.head(3)
# Out:
#   year, month, day, RMM1, RMM2, phase, amplitude.  Missing Value= 1.E36 or 999
# 0          1974           6           1   1.63447...
# 1          1974           6           2   1.60289...
# 2          1974           6           3   1.51625...

# %%
RMM_meta_split = list(RMM_meta.iloc[:,0])

# %%
date = []
phase = []
amp = []
RMM = pd.DataFrame()

for i in range(len(RMM_meta_split)):
    row = RMM_meta_split[i].split()
    
    
    year = row[0]
    month = row[1]
    day  = row[2]
    doy = pd.to_datetime(year + month + day, format = '%Y%m%d')
    date.append(doy)
    
    RMM_phase = float(row[5])
    
    if RMM_phase < 100 and RMM_phase > 0.1:
        phase.append(RMM_phase)
    else:
        phase.append(np.nan)
    
    RMM_amp = float(row[6])
    if RMM_amp < 100 and RMM_amp > 0.001:
        amp.append(RMM_amp)
    else:
        amp.append(np.nan)
    
    
    
    
RMM['Date']  = date
RMM['Phase'] = phase
RMM['Amplitude'] = amp
RMM = RMM.set_index('Date')

# %%
RMM['Phase']['2016':'2018'].plot()

# %%
RMM['Amplitude']['2016':'2018'].plot()

# %%
# RMM.to_csv('RMM.csv')
