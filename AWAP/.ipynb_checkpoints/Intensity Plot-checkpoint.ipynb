# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Preamble" data-toc-modified-id="Preamble-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Preamble</a></span></li><li><span><a href="#Plots" data-toc-modified-id="Plots-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Plots</a></span><ul class="toc-item"><li><span><a href="#Mid-point-log" data-toc-modified-id="Mid-point-log-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Mid point log</a></span></li><li><span><a href="#Intensity" data-toc-modified-id="Intensity-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Intensity</a></span></li><li><span><a href="#Fraction" data-toc-modified-id="Fraction-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Fraction</a></span></li><li><span><a href="#Running-All" data-toc-modified-id="Running-All-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Running All</a></span></li></ul></li><li><span><a href="#PDF's" data-toc-modified-id="PDF's-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>PDF's</a></span><ul class="toc-item"><li><span><a href="#Functions" data-toc-modified-id="Functions-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Functions</a></span></li><li><span><a href="#Plot" data-toc-modified-id="Plot-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Plot</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Preamble

# %%
import xarray as xr
import numpy as np
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
from dask.diagnostics import ProgressBar
import matplotlib.colors as colors
import datetime as dt

# %%
rb = plt.cm.RdBu
bm = plt.cm.Blues

# %%
path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Active_90I.nc'
Active_90I = xr.open_dataset(path) 

path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Inactive_90I.nc'
Inactive_90I = xr.open_dataset(path) 

path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Suppressed_90I.nc'
Suppressed_90I = xr.open_dataset(path)

# %%
path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Active_frac_90I.nc'
Active__frac_90I = xr.open_dataset(path) 

path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Inactive_frac_90I.nc'
Inactive_frac_90I = xr.open_dataset(path) 

path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Suppressed_frac_90I.nc'
Suppressed_frac_90I = xr.open_dataset(path) 

Frac_90I = {'Active':Active__frac_90I , "Inactive":Inactive_frac_90I,'Suppressed':Suppressed_frac_90I }

# %%
path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Active_frac_95I.nc'
Active__frac_95I = xr.open_dataset(path) 

path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Inactive_frac_95I.nc'
Inactive_frac_95I = xr.open_dataset(path) 

path ='/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Scripts/AWAP/Suppressed_frac_95I.nc'
Suppressed_frac_95I = xr.open_dataset(path)

# %%
Frac_95I = {'Active':Active__frac_95I , "Inactive":Inactive_frac_95I,'Suppressed':Suppressed_frac_95I }

# %%
Suppressed_frac_95I
# Out:
# <xarray.Dataset>
# Dimensions:    (lat: 53, lon: 178, month: 6)
# Coordinates:
#   * lon        (lon) float64 112.0 112.2 112.5 112.8 113.0 113.2 113.5 113.8 ...
#   * lat        (lat) float64 -23.0 -22.75 -22.5 -22.25 -22.0 -21.75 -21.5 ...
#   * month      (month) int64 10 11 12 1 2 3
# Data variables:
#     precip     (month, lat, lon) float64 ...
#     RMM_Phase  (month, lon) float64 ...
#     RMM_Amp    (month, lon) float64 ...

# %% [markdown]
# # Plots

# %% [markdown]
# ## Mid point log

# %%
class MidpointNormalizeLog(colors.LogNorm):
    def __init__(self, vmin, vmax, midpoint):
        self.midpoint = midpoint
        super().__init__(vmin=vmin, vmax=vmax)
        
    def __call__(self, value, clip=None):
        original = super().__call__(value, clip)
        procmid = super().__call__(self.midpoint, clip)
        
        x, y = [0, procmid, 1], [0, 0.5, 1]
        return np.ma.masked_array(np.interp(original, x, y), np.isnan(original))

# %% [markdown]
# ## Intensity

# %%
fig  = plt.figure(figsize = (15,15))
title_size = 15
month = 12
vmax = 70

plot_num = 0
       
plot_num += 1            
ax = fig.add_subplot(3,1,plot_num, projection = ccrs.PlateCarree())
Active_90I.sel(month = month).precip.plot(ax = ax,  cmap = bm,vmax = vmax, add_colorbar = False)                      
ax.coastlines()
plt.title('Active')


plot_num += 1
ax = fig.add_subplot(3,1,plot_num, projection = ccrs.PlateCarree())
Suppressed_90I.sel(month = month).precip.plot(ax = ax, cmap = bm,vmax = vmax, add_colorbar = False)    
ax.coastlines()
plt.title('Suppressed')


plot_num += 1
ax = fig.add_subplot(3,1,plot_num, projection = ccrs.PlateCarree())
plot = Inactive_90I.sel(month = month).precip.plot(ax = ax,cmap = bm,vmax = vmax, add_colorbar = False)   
ax.coastlines()
plt.title('Inactive')


############ Color Bar


ticks= np.arange(0,80,10)
boundaries = np.arange(5,85,10)
cax = fig.add_axes([.3, 0.92, 0.4,0.01])

cbar = plt.colorbar(plot, orientation = 'horizontal',ticks= ticks,boundaries=boundaries, cax = cax)
ticks[0] -= 0.1
cbar.ax.tick_params(labelsize = 10)
cbar.ax.set_xticklabels([str(i) for i in ticks])
cbar.set_label('Relative Likelihood of Rainfall > 90th Percentile'
                  , fontsize = 12, labelpad = 10)                                                          




fig.tight_layout(rect=[0, 0.03, 1, 0.85])
# Out:
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ## Fraction

# %%
def geo_plot(data, month,title = '',cmap = plt.cm.Blues,save_fig = 0):

    fig  = plt.figure(figsize = (15,15))
    title_size = 15
    vmax = 2.5
    vmin = 0.5


    plot_num = 0

    plot_num += 1            
    ax = fig.add_subplot(3,1,plot_num, projection = ccrs.PlateCarree())
    
    active = data['Active']
    active = active.where(active.precip != 0, vmin)
    active.sel(month = month).precip.plot(ax = ax,  cmap = cmap, vmin = vmin,vmax = vmax,
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))                      
    ax.coastlines()
    plt.title('Active',fontsize = title_size )


    plot_num += 1
    ax = fig.add_subplot(3,1,plot_num, projection = ccrs.PlateCarree())
    
    suppressed = data['Suppressed']
    suppressed = suppressed.where(suppressed.precip != 0, vmin)
    suppressed.sel(month = month).precip.plot(ax = ax, cmap = cmap, vmin =vmin,vmax = vmax,
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))    
    ax.coastlines()
    plt.title('Suppressed',fontsize = title_size )


    plot_num += 1
    ax = fig.add_subplot(3,1,plot_num, projection = ccrs.PlateCarree())
    inactive = data['Inactive']
    inactive = inactive.where(inactive.precip != 0, vmin)
    inactive = inactive.dropna(dim = 'lat',how = 'all')
    plot = inactive.sel(month = month).precip.plot(ax = ax,cmap = cmap, vmin = vmin,vmax = vmax, 
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))
    ax.coastlines()
    plt.title('Inactive',fontsize = title_size )


    ############ Color Bar
    step = 0.1

    ticks= [0.51,1,1.5,2]
    boundaries = np.arange(0.1,vmax - step,step)
    cax = fig.add_axes([.3, 0.92, 0.4,0.01])

    cbar = plt.colorbar(plot, orientation = 'horizontal',ticks= ticks,boundaries=boundaries, cax = cax)
    ticks[0] -= 0.01
    cbar.ax.tick_params(labelsize = 10)
    cbar.ax.set_xticklabels([str(i) for i in ticks])                                                      




    fig.tight_layout(rect=[0, 0.03, 1, 0.85])

# %%
data = Frac_90I
month = 1
title = 'Relative Likelihood of Rainfall > 90th Percentile'


geo_plot(data, month,title = title,cmap = rb, save_fig = 0)
# Out:
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %%
def geo_plot_2(data1,data2, month,title = '',cmap = plt.cm.Blues,save_fig = 0):

    fig = plt.figure(figsize = (15,12))
    title_size = 15
    vmax = 2
    vmin = 0.2
    month_name = dt.date(2015, int(month), 1).strftime('%B')
    fig.suptitle(month_name + " : " + title, fontsize = 20)

    plot_num = 0
    #############################
    plot_num += 1            
    ax = fig.add_subplot(3,2,plot_num, projection = ccrs.PlateCarree())

    active = data1['Active']
    active = active.where(active.precip != 0, vmin)
    active.sel(month = month).precip.plot(ax = ax,  cmap = cmap, vmin = vmin,vmax = vmax,
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))                      
    ax.coastlines()

    ax.set_title('90th Percentile', fontsize = title_size )
    
    plot_num += 1            
    ax = fig.add_subplot(3,2,plot_num, projection = ccrs.PlateCarree())
    
    active = data2['Active']
    active = active.where(active.precip != 0, vmin)
    active.sel(month = month).precip.plot(ax = ax,  cmap = cmap, vmin = vmin,vmax = vmax,
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))                      
    ax.coastlines()
    ax.set_title('95th Percentile', fontsize = title_size )

    
    
    
    #############################
    

    plot_num += 1
    ax = fig.add_subplot(3,2,plot_num, projection = ccrs.PlateCarree())
    
    suppressed = data1['Suppressed']
    suppressed = suppressed.where(suppressed.precip != 0, vmin)
    suppressed.sel(month = month).precip.plot(ax = ax, cmap = cmap, vmin =vmin,vmax = vmax,
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))    
    ax.coastlines()
    ax.set_title('', fontsize = title_size )


    
    plot_num += 1
    ax = fig.add_subplot(3,2,plot_num, projection = ccrs.PlateCarree())
    
    suppressed = data2['Suppressed']
    suppressed = suppressed.where(suppressed.precip != 0, vmin)
    suppressed.sel(month = month).precip.plot(ax = ax, cmap = cmap, vmin =vmin,vmax = vmax,
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))    
    ax.coastlines()
    ax.set_title('', fontsize = title_size )



    
    #############################
    plot_num += 1
    ax = fig.add_subplot(3,2,plot_num, projection = ccrs.PlateCarree())
    inactive = data1['Inactive']
    inactive = inactive.where(inactive.precip != 0, vmin)
    inactive = inactive.dropna(dim = 'lat',how = 'all')
    plot = inactive.sel(month = month).precip.plot(ax = ax,cmap = cmap, vmin = vmin,vmax = vmax, 
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))
    ax.coastlines()
    ax.set_title('', fontsize = title_size )


    
    plot_num += 1
    ax = fig.add_subplot(3,2,plot_num, projection = ccrs.PlateCarree())
    inactive = data2['Inactive'].sel(month = month)
    inactive = inactive.fillna(10000)
    inactive = inactive.where(inactive.precip > 0.5, 0.5)
    inactive  = inactive.where(inactive.precip < 8000)
#     inactive = inactive.where(inactive.precip > vmin, vmin)

    plot = inactive.precip.plot(ax = ax,cmap = cmap, vmin = vmin,vmax = vmax, 
                                            add_colorbar = False,
                                            norm = MidpointNormalizeLog(vmin = vmin, vmax = vmax, midpoint=1))
    ax.coastlines()
    ax.set_title('', fontsize = title_size )
    ############ Color Bar
    step = 0.1

    ticks= np.array([0.4,0.6,0.8,1,1.2,1.4,1.6,1.8,2])
    tick_labels = [str(i) for i in ticks]
    ticks = ticks - 0.05
    boundaries = np.arange(0.1,vmax - step,step)
    cax = fig.add_axes([.3, 0.92, 0.4,0.01])

    cbar = plt.colorbar(plot, orientation = 'horizontal',ticks= ticks,boundaries=boundaries, cax = cax,
                       extend = 'both')
#     ticks[0] -= 0.01
    cbar.ax.tick_params(labelsize = 10)
    cbar.ax.set_xticklabels(tick_labels) 
    cbar.set_label('Ratio'
                  , fontsize = 12, labelpad = 10)    
    
    xdip = -1.1
    plt.text(xdip,-25,'Enhanced', fontsize = title_size)
    plt.text(xdip,-50,'Suppressed', fontsize = title_size)
    plt.text(xdip,-75,'Inactive', fontsize = title_size)


    fig.tight_layout(rect=[0, 0.03, 1, 0.89])


    #####
    if save_fig:
        directory = '/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Current Project/AWAP/Intensity/'
        fig.savefig(directory + title + '.png',bbox_inches = 'tight')

# %%
data1 = Frac_90I
data2 = Frac_95I
month = 1
title = 'Intensity Ratio of Rainfall > 90th and 95th Percentile'


geo_plot_2(data1, data2, month,title = title,cmap = rb, save_fig = 1)
# Out:
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %% [markdown]
# ## Running All

# %%
data1 = Frac_90I
data2 = Frac_95I
months = [10,11,12,1,2,3]
title = 'Intensity Increase of Rianfall > 90th and 95th Percentile'

for month in months:
    geo_plot_2(data1, data2, month,title = title,cmap = rb, save_fig = 1)
# Out:
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:2267: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# /home/student.unimelb.edu.au/aborowiak/anaconda3/lib/python3.6/site-packages/matplotlib/colors.py:1031: RuntimeWarning: invalid value encountered in less_equal
#   mask |= resdat <= 0

# %% [markdown]
# # PDF's

# %% [markdown]
# ## Functions

# %%
#This function takes all of the precip values and terns them into one numpy array. This enables them to 
#be plotted as a PDF

def flatten_xarray(xarray):
    narray = np.array(xarray.precip.values).flatten()
    narray = narray[~np.isnan(narray)]
    
    return narray

# %%
# This function finds the value nearest to 1. This is used to find in the plot where to change the color
# from red to blue when crossing over 1. 

def find_nearest(array, value):
    array = np.asarray(array)
    idx = (np.abs(array - value)).argmin()
    return idx

# %%
#Plots a pdf
# alpha = 0 if just the outline (no hist)
# line = False will give you just the histogram, no ourline
# window is the width of the rolling mean


def plot_pdf(flat_array, ax,alpha,line, window = 3 , color = 'b', label = ' '):
    bins = np.logspace(np.log10(0.1),np.log10(5),50)
    #The histogram
    N,bins_2, patches = ax.hist(flat_array, bins = bins,density = True, range = (0,5),
                                alpha = alpha)
    
    #This is needed so that the outline gets centers properlly
    delta =  (bins[:49] - bins[1:])/2
    bins_sub = bins[1:]+ 3*delta #3 just seems to work (maybe this is the length of the rolling mean)
    
    #This is the line plot
    if line:
        N_pd = pd.Series(N)
        N_smooth = N_pd.rolling(window = window).mean() #Rolling mean in order to smooth out the data
        ax.plot(bins_sub,N_smooth, color = color, label  = label)
    
    #Setting the x-axis so that it is in a log scale
    ax.set_xscale('log')
    
    #This is only needed if the histogram is here. This turns the plot from 0 to 1 into red
    # (reduced change of extreme rainfall)
    for i in range(0,find_nearest(bins, 1)):
        patches[i].set_facecolor('indianred')
        
    return N,bins_2, patches

# %%
def PDF_plot_2(data,title = '', alpha = 1, line = True,save_fig = 1 , percentile = 90):

    fig = plt.figure(figsize = (14,18))

    title_size = 15
    labelpad = 50
    title = 'Probability Density Function of Increase in Rainfall Intensity > ' + str(percentile) + 'th Percentile'
    fig.suptitle(title, fontsize = 20)

    #Returning all of the medians so that I can get a bat plot lates
    act_meds_l = []
    inact_meds_l = []
    sup_meds_l = []




    ################################################################################### 90th

    num_rows = 6
    num_cols = 1
    months = [10,11,12,1,2,3]

    
    plot_num = 1
    for month in months:
        
        ax = fig.add_subplot(num_rows,num_cols,plot_num)

        ################### Active
        act = data['Active']
        flat_act = flatten_xarray(act.sel(month = month))
        N_act,bins_2, patches = plot_pdf(flat_act, ax, alpha = alpha,line= True, color = 'b', label = 'Active')

        ####################### Supressed

        flat_sup = flatten_xarray(data['Suppressed'].sel(month = month))
        N,bins_2, patches = plot_pdf(flat_sup, ax, alpha = alpha,line= True, color = 'r', label = 'Suppressed')

        ################### Inactive


        flat_inact = flatten_xarray(data['Inactive'].sel(month = month))
        N,bins_2, patches = plot_pdf(flat_inact, ax,alpha = alpha, line= True,color = 'y',label = 'Inactive')

        ################## Additional

        #     ax.plot([1,1],[0,2], linestyle = ':') #The line at 1 

        #Medians
        y_max = 3.5
        
        
        med_act = np.median(flat_act)
        med_sup = np.median(flat_sup)
        med_inact = np.median(flat_inact)

        ax.plot([med_act,med_act],[0,y_max], linestyle = ':', color = 'b')
        ax.plot([med_sup,med_sup],[0,y_max], linestyle = ':', color = 'r')
        ax.plot([med_inact,med_inact],[0,y_max], linestyle = ':', color= 'y')

        
        
        #This doesn't actually appear on the plot. Just a place holder adding the median into the legend
        ax.plot([100,100],[0,0.001], linestyle = ':', color = 'k', label = 'Median')

        #Saving all the medians into a list
        act_meds_l.append(med_act)
        sup_meds_l.append(med_sup)
        inact_meds_l.append(med_inact)

        ###
        month_name = dt.date(2015, int(month), 1).strftime('%B')
        ax.set_ylabel(month_name, fontsize = title_size ,rotation = 0, labelpad = labelpad)
        xticks = [0.25,0.5,1,2,3,5]
        ax.set_xticks(xticks)
        ax.set_xticklabels([str(i) for i in xticks])
        if plot_num == 1:
            ax.legend()
        #         ax.legend({'Suppressed','Inactive','Active'})
        ax.set_ylim(0,y_max)
        ax.set_xlim(0.15, 4)



        plot_num += 1

    fig.tight_layout(rect=[0, 0.03, 1, 0.96])
    
    if save_fig:
        directory =  '/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Current Project/AWAP/Intensity/'
        fig.savefig( directory + title + '.png', bbox_inches = 'tight', )
        
    medians = pd.DataFrame({'Active':act_meds_l,'Suppressed':sup_meds_l, 'Inactive':inact_meds_l})
    return medians

# %% [markdown]
# ## Plot

# %%
fracs = {'90':Frac_90I,'95':Frac_95I}

# %%
data = fracs['90']

meds_90 = PDF_plot_2(data,title = '', alpha = 0, line = True,save_fig = 1, percentile = 90)

# %%
data = fracs['95']

meds_95 = PDF_plot_2(data,title = '', alpha = 0, line = True,save_fig = 1, percentile = 95)

# %%
meds_90
# Out:
#      Active  Suppressed  Inactive
# 0  1.073770    0.816513  0.948859
# 1  0.999911    0.984403  0.969895
# 2  1.070630    0.915822  0.975352
# 3  1.136182    0.881951  0.988448
# 4  1.098713    0.846024  1.013207
# 5  1.027107    0.944226  0.970209

# %%
meds_95['Active']
# Out:
#      Active  Suppressed  Inactive
# 0  1.054155    0.769350  0.943185
# 1  0.982652    0.979769  0.952526
# 2  1.054567    0.904913  0.972299
# 3  1.116405    0.867510  0.988446
# 4  1.077224    0.841599  1.003853
# 5  1.016384    0.949914  0.938987

# %%
def median_barplots(data, name, save_fig):
    fig = plt.figure(figsize = (10,4.5))

    width = 0.25


    index_num = np.arange(0,6,1)
    index = ['Oct','Nov','Dec','Jan','Feb','Mar']


    r1 = np.arange(len(index))
    plt.bar(index_num, data['Active'], width = width,color= 'b', label = 'Enhanced')

    r2 = [x + width for x in r1]
    plt.bar(r2, data['Suppressed'], width = width,color= 'y', label = 'Suppressed')
    
    r3 = [x + width for x in r2]
    plt.bar(r3, data['Inactive'], width = width,color= 'r' , label = 'Inactive')



    plt.plot([-3,10],[1,1], color = 'r', linestyle = ':')

    plt.xticks(index_num + width,index);
    plt.ylim([0.7,1.2])
    plt.xlim([-0.25,5.75])
    plt.legend()
    plt.xlabel('Month')
    plt.ylabel('Ratio')
    
    plt.title(name)
    if save_fig:
        directory =  '/home/student.unimelb.edu.au/aborowiak/Desktop/Code/Current Project/AWAP/Intensity/'
        fig.savefig( directory + name + '.png', bbox_inches = 'tight', dpi = 400)

# %%
percentile = '90th'
data = meds_90
name =  'Median of Intensity Ratio of Rainfall >' + percentile  + ' Percentile'
median_barplots(data, name, save_fig = 1)

# %%
percentile = '95th'
data = meds_95
name =  'Median of Intensity Ratio of Rainfall >' + percentile  + ' Percentile'
median_barplots(data, name, save_fig = 1)
